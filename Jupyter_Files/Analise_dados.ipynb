# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Analise da tabela de crimes 2016</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Turma 3ECR</b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Grupo:</b>
#
# Alex Matos    RM:
#
# Axel Lafuente Gutierrez RM:
#
# Guilherme Condini RM:
#
# Larissa Toledo RM:
#
# Rodrigo Kenji RM:
# </div>

# %% [markdown]
# Para fazer esta analise, primeiro começamos fazendo um import das bibliotecas Python

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Agora, importamos os arquivos csv para o notebook:

# %%
tab_desc = pd.read_csv("crimes_2016-desc.csv")
tab = pd.read_csv("crimes_2016.csv")
# Out:
# /root/anaconda3/envs/fiap-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Agora vemos seus conteudos, para que possamos entender com que dados iremos trabalhar

# %%
tab_desc
# Out:
#                     NUM_BO                                  Ano da ocorrencia
# 0                   ANO_BO                                       Número do BO
# 1             ID_DELEGACIA  Código da delegacia responsável pelo registro ...
# 2        NOME_DEPARTAMENTO             Departamento responsável pelo registro
# 3           NOME_SECCIONAL      Delegacia Seccional responsável pelo registro
# 4                DELEGACIA                Delegacia responsável pelo registro
# 5   NOME_DEPARTAMENTO_CIRC  Departamento responsável pela área onde houve ...
# 6      NOME_SECCIONAL_CIRC  Delegacia Seccional responsável pela área onde...
# 7      NOME_DELEGACIA_CIRC  Delegacia responsável pela área onde houve a o...
# 8                      ANO                                    Ano do registro
# 9                      MES                                    mês do registro
# 10      DATA_OCORRENCIA_BO                                       data do fato
# 11      HORA_OCORRENCIA_BO                                       hora do fato
# 12             FLAG_STATUS             Indica se é crime consumado ou tentado
# 13                 RUBRICA                    Natureza juridica da ocorrencia
# 14           DESDOBRAMENTO  Desdobramentos juridicos envolvidos na ocorrencia
# 15                 CONDUTA  Tipo de local ou circunstancia que qualifica a...
# 16                LATITUDE                            coordenadas geograficas
# 17               LONGITUDE                            coordenadas geograficas
# 18                  CIDADE                Municipio de registro da ocorrencia
# 19              LOGRADOURO                                 Logradouro do fato
# 20       NUMERO_LOGRADOURO                       Número do Logradouro do fato
# 21             FLAG_STATUS             Indica se é crime consumado ou tentado
# 22       DESCR_TIPO_PESSOA  indica o tipo de envolvimento da pessoa na oco...
# 23             CONT_PESSOA           indica ordem de registro da pessoa no BO
# 24             SEXO_PESSOA                         sexo da pessoa relacionada
# 25            IDADE_PESSOA                        idade da pessoa relacionada
# 26                     COR                     cor/raça da pessoa relacionada
# 27         DESCR_PROFISSAO                                PROFISSÃO DA PESSOA
# 28    DESCR_GRAU_INSTRUCAO                         grau de intrução da pessoa

# %%
tab
# Out:
#         NUM_BO  ANO_BO  ID_DELEGACIA  \
# 0        10957    2016         20249
# 1         1672    2016         20230
# 2          211    2016         10376
# 3         4438    2016         10323
# 4       676155    2016        900020
# ...        ...     ...           ...
# 49995     2063    2016         10374
# 49996  1356710    2016        900020
# 49997     1318    2016         10359
# 49998     5536    2016         10336
# 49999     1238    2016         20301
#
#                               NOME_DEPARTAMENTO  \
# 0      DECAP
# 1      DECAP
# 2      DECAP
# 3      DECAP
# 4      DIPOL - DEPTO DE INTELIGENCIA
# ...                                         ...
# 49995  DECAP
# 49996  DIPOL - DEPTO DE INTELIGENCIA
# 49997  DECAP
# 49998  DECAP
# 49999  DECAP
#
#                                  NOME_SECCIONAL  \
# 0      DEL.SEC.8º SAO MATEUS
# 1      DEL.SEC.5º LESTE
# 2      DEL.SEC.3º OESTE
# 3      DEL.SEC.3º OESTE
# 4      DELEGACIA ELETRONICA
# ...                                         ...
# 49995  DEL.SEC.6º SANTO AMARO
# 49996  DELEGACIA ELETRONICA
# 49997  DEL.SEC.5º LESTE
# 49998  DEL.SEC.4º NORTE
# 49999  DEL.SEC.7º ITAQUERA
#
#                             DELEGACIA  \
# 0      49º D.P.  SAO MATEUS
# 1      30º D.P.  TATUAPE
# 2      09ª DEL.DEF.MUL. OESTE
# 3      23º D.P.  PERDIZES
# 4      DELEGACIA ELETRONICA
# ...                               ...
# 49995  101º D.P. JDIM IMBUIAS
# 49996  DELEGACIA ELETRONICA
# 49997  57º D.P. PARQUE DA MOOCA
# 49998  73º D.P. JACANA
# 49999  103º D.P. COHABII/ITAQU.
#
#                          NOME_DEPARTAMENTO_CIRC  \
# 0      DECAP
# 1      DECAP
# 2      DECAP
# 3      DECAP
# 4      DECAP
# ...                                         ...
# 49995  DECAP
# 49996  DECAP
# 49997  DECAP
# 49998  DECAP
# 49999  DECAP
#
#                             NOME_SECCIONAL_CIRC  \
# 0      DEL.SEC.8º SAO MATEUS
# 1      DEL.SEC.5º LESTE
# 2      DEL.SEC.3º OESTE
# 3      DEL.SEC.3º OESTE
# 4      DEL.SEC.1º CENTRO
# ...                                         ...
# 49995  DEL.SEC.6º SANTO AMARO
# 49996  DEL.SEC.4º NORTE
# 49997  DEL.SEC.1º CENTRO
# 49998  DEL.SEC.4º NORTE
# 49999  DEL.SEC.8º SAO MATEUS
#
#                   NOME_DELEGACIA_CIRC   ANO  ...  FLAG_STATUS  \
# 0      49º D.P.  SAO MATEUS            2016  ...            C
# 1      30º D.P.  TATUAPE               2016  ...            C
# 2      87º D.P. V. P. BARRETO          2016  ...            C
# 3      23º D.P.  PERDIZES              2016  ...            C
# 4      04º D.P. CONSOLAÇÃO             2016  ...            C
# ...                               ...   ...  ...          ...
# 49995  85º D.P. JARDIM MIRNA           2016  ...            C
# 49996  38º D.P.  VILA AMALIA           2016  ...            C
# 49997  08º D.P. BRAS                   2016  ...            C
# 49998  28º D.P.  FREGUESIA DO O        2016  ...            C
# 49999  69º D.P. TEOTONIO VILELA        2016  ...            C
#
#                              RUBRICA DESDOBRAMENTO                   CONDUTA  \
# 0              A.I.-Furto (art. 155)           NaN                RESIDENCIA
# 1                   Roubo (art. 157)           NaN                TRANSEUNTE
# 2      Lesão corporal (art 129 § 9º)           NaN                       NaN
# 3          Lesão corporal (art. 129)           NaN                       NaN
# 4                   Furto (art. 155)           NaN                TRANSEUNTE
# ...                              ...           ...                       ...
# 49995  Lesão corporal (art 129 § 9º)           NaN                       NaN
# 49996               Furto (art. 155)           NaN  INTERIOR ESTABELECIMENTO
# 49997               Roubo (art. 157)           NaN       INTERIOR DE VEICULO
# 49998               Furto (art. 155)           NaN                   VEICULO
# 49999               Furto (art. 155)           NaN                    OUTROS
#
#         LATITUDE  LONGITUDE                                    CIDADE  \
# 0     -23.594489 -46.482766  S.PAULO
# 1     -23.542544 -46.561665  S.PAULO
# 2     -23.481277 -46.718199  S.PAULO
# 3     -23.531843 -46.664163  S.PAULO
# 4     -23.553752 -46.658809  S.PAULO
# ...          ...        ...                                       ...
# 49995 -23.746575 -46.708184  S.PAULO
# 49996 -23.477550 -46.645512  S.PAULO
# 49997 -23.548181 -46.618955  S.PAULO
# 49998 -23.492218 -46.696220  S.PAULO
# 49999 -23.588680 -46.499830  S.PAULO
#
#                                      LOGRADOURO NUMERO_LOGRADOURO  \
# 0      RUA ANDRE DE ALMEIDA                                  1260
# 1      RUA MONTE SERRAT                                       500
# 2      AVENIDA COMENDADOR FEIZ ZARZUR                         100
# 3      AVENIDA FRANCISCO MATARAZZO                           1028
# 4      RUA BELA CINTRA                                        670
# ...                                         ...               ...
# 49995  RUA OVIDIO COLLESI                                    19.0
# 49996  AVENIDA DOUTOR FRANCISCO RANIERI                     834.0
# 49997  RUA PRUDENTE DE MORAIS                                   1
# 49998  AVENIDA ITABERABA                                      993
# 49999  RUA PASTOR AGENOR CALDEIRA DINIZ                      72.0
#
#       FLAG_STATUS.1
# 0                 C
# 1                 C
# 2                 C
# 3                 C
# 4                 C
# ...             ...
# 49995             C
# 49996             C
# 49997             C
# 49998             C
# 49999             C
#
# [50000 rows x 21 columns]

# %%
len(tab)
# Out:
# 50000

# %%
tab.describe()
# Out:
#              NUM_BO       ANO_BO   ID_DELEGACIA      ANO           MES  \
# count  5.000000e+04  50000.00000   50000.000000  50000.0  50000.000000
# mean   2.912170e+05   2016.00980  326619.125300   2016.0      6.511960
# std    4.852093e+05      0.09851  415996.189602      0.0      3.445695
# min    1.000000e+00   2016.00000   10004.000000   2016.0      1.000000
# 25%    2.015000e+03   2016.00000   10363.000000   2016.0      3.000000
# 50%    5.331500e+03   2016.00000   30212.000000   2016.0      7.000000
# 75%    4.631302e+05   2016.00000  900020.000000   2016.0     10.000000
# max    1.673585e+06   2017.00000  990900.000000   2016.0     12.000000
#
#            LATITUDE     LONGITUDE
# count  47231.000000  47231.000000
# mean     -23.571720    -46.609600
# std        0.084890      0.135791
# min      -24.004595    -47.158300
# 25%      -23.632681    -46.696877
# 50%      -23.556987    -46.627073
# 75%      -23.519057    -46.519337
# max      -23.217859    -45.842966

# %%
tab.columns
# Out:
# Index(['NUM_BO', 'ANO_BO', 'ID_DELEGACIA', 'NOME_DEPARTAMENTO',
#        'NOME_SECCIONAL', 'DELEGACIA', 'NOME_DEPARTAMENTO_CIRC',
#        'NOME_SECCIONAL_CIRC', 'NOME_DELEGACIA_CIRC', 'ANO', 'MES',
#        'FLAG_STATUS', 'RUBRICA', 'DESDOBRAMENTO', 'CONDUTA', 'LATITUDE',
#        'LONGITUDE', 'CIDADE', 'LOGRADOURO', 'NUMERO_LOGRADOURO',
#        'FLAG_STATUS.1'],
#       dtype='object')

# %%
tmp = tab[['ANO_BO', 'DELEGACIA', 'CIDADE', 'RUBRICA']]

# %%
tmp
# Out:
#        ANO_BO                       DELEGACIA  \
# 0        2016  49º D.P.  SAO MATEUS
# 1        2016  30º D.P.  TATUAPE
# 2        2016  09ª DEL.DEF.MUL. OESTE
# 3        2016  23º D.P.  PERDIZES
# 4        2016  DELEGACIA ELETRONICA
# ...       ...                             ...
# 49995    2016  101º D.P. JDIM IMBUIAS
# 49996    2016  DELEGACIA ELETRONICA
# 49997    2016  57º D.P. PARQUE DA MOOCA
# 49998    2016  73º D.P. JACANA
# 49999    2016  103º D.P. COHABII/ITAQU.
#
#                                          CIDADE                        RUBRICA
# 0      S.PAULO                                           A.I.-Furto (art. 155)
# 1      S.PAULO                                                Roubo (art. 157)
# 2      S.PAULO                                   Lesão corporal (art 129 § 9º)
# 3      S.PAULO                                       Lesão corporal (art. 129)
# 4      S.PAULO                                                Furto (art. 155)
# ...                                         ...                            ...
# 49995  S.PAULO                                   Lesão corporal (art 129 § 9º)
# 49996  S.PAULO                                                Furto (art. 155)
# 49997  S.PAULO                                                Roubo (art. 157)
# 49998  S.PAULO                                                Furto (art. 155)
# 49999  S.PAULO                                                Furto (art. 155)
#
# [50000 rows x 4 columns]

# %%
tmp.CIDADE == "S.PAULO"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49995    False
# 49996    False
# 49997    False
# 49998    False
# 49999    False
# Name: CIDADE, Length: 50000, dtype: bool

# %%
tab.loc[tab.CIDADE == "S.PAULO", :]
# Out:
# Empty DataFrame
# Columns: [NUM_BO, ANO_BO, ID_DELEGACIA, NOME_DEPARTAMENTO, NOME_SECCIONAL, DELEGACIA, NOME_DEPARTAMENTO_CIRC, NOME_SECCIONAL_CIRC, NOME_DELEGACIA_CIRC, ANO, MES, FLAG_STATUS, RUBRICA, DESDOBRAMENTO, CONDUTA, LATITUDE, LONGITUDE, CIDADE, LOGRADOURO, NUMERO_LOGRADOURO, FLAG_STATUS.1]
# Index: []
#
# [0 rows x 21 columns]
